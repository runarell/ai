# %%
# 001
print('Hello World')

# %%
# 002
print("Mary's cosmetics")
print('Mary\'s cosmetics')

# %%
# 003
print('신씨가 소리질렀다. "도둑이야".')
print('신씨가 소리질렀다. \"도둑이야\".')
# Out:
# 신씨가 소리질렀다. "도둑이야".
# 신씨가 소리질렀다. "도둑이야".

# %%
# 004
print('"c:\Windows"')
# Out:
# "c:\Windows"

# %%
# 005
print("안녕하세요.\n만나서\t\t방갑습니다.")
# \n : 줄바꿈 (개항)
# \t : 일정간격 뛰기
# Out:
# 안녕하세요.
# 만나서		방갑습니다.

# %%
# 006
print("오늘은", "일요일")
# 오늘은 일요일

# 상세하게 작성
# 여러 값은 print 에서 ,로 구분하는데 "오늘은","일요일" 사이에 공백이 들어가서 출력됨

# %%
# 007
print("naver","kakao","sk","samsung", sep=';')
# Out:
# naver;kakao;sk;samsung

# %%
#008
print("naver","kakao","sk","samsung", sep='/')
# Out:
# naver/kakao/sk/samsung

# %%
# 009
print("first", end='\t');print("second")
# Out:
# first	second

# %%
#010
ave = p5/3
print( ave )
# Out:
# 1.6666666666666667

# %%
#011
samsong = 50000
ave = round(samsong/10,2)

print(f'평가 금액 : {ave} 입니다.')
# Out:
# 평가 금액 : 5000.0 입니다.

# %%
# 012
Cap = 298000000000000
price = 50000
per = 15.79

# pritn(시가총액, typpe(시가총액))
#변수명에 할당 하는것을 바인딩

# %%
# 013
s = "hello"
t = "python"

print(f'{s}! {t}')
# Out:
# hello! python

# %%
# 014
2+2*3
# 결과값 : 8
# Out:
# 8

# %%
#015
a = "132"
print(type(a))
# class 'str'
# Out:
# <class 'str'>

# %%
#016
num_str = "720"
num_int = int(num_str)
print(type(num_int))
# Out:
# <class 'int'>

# %%
# 017
num = 100
num_str = str(num)
print(type(num_str))
# Out:
# <class 'str'>

# %%
# 018
str = "15.79"
num_float = float(str)
print(type(num_float))
# Out:
# <class 'float'>

# %%
# 019
year = "2020"
year_int = int(year)

print(f'재작년 : {year_int -2}\n 작년 : {year_int -1}\n 올해 : {year_int}')
# Out:
# 재작년 : 2018
#  작년 : 2019
#  올해 :2020

# %%
# 020
monny = 48584
month = 36

print (f'총금액 : {monny * month}')
# Out:
# 총금액 : 1749024
